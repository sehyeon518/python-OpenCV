# %% [markdown]
# # 예제 4.4 화소 접근 2: 컬러 영상(BGR)

# %%
import cv2

img = cv2.imread('../sample/why.jpeg')

# %%
img[50, 50] = [255, 0, 0] # color 변경 -> Blue
print(img[50, 50:150])
# Out:
# [[255   0   0]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
#  [242 214 214]
# ...

# %%
img[0:100, 0:200] = [255, 0, 0]

# %%
cv2.imshow('img', img)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [markdown]
# ![img_screenshot_04 01 2023](https://user-images.githubusercontent.com/84698896/210501903-aac00dc6-7be3-4b8a-a905-22e1bae0e9be.png)
